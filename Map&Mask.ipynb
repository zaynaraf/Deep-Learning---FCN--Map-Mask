# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gdown

# Replace FILE_ID with the actual ID of your file from Google Drive
file_id = '1SQnUPcdqStHvewQtQLHi5QhmmvOZw_jI' #import the dataset zip uploaded in my google drive
gdown.download(f'https://drive.google.com/uc?id={file_id}', 'dataset.zip', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1SQnUPcdqStHvewQtQLHi5QhmmvOZw_jI
# From (redirected): https://drive.google.com/uc?id=1SQnUPcdqStHvewQtQLHi5QhmmvOZw_jI&confirm=t&uuid=5ed827bb-72f7-4c65-8aab-e4de5d16b64b
# To: /content/dataset.zip
# 100%|██████████| 191M/191M [00:01<00:00, 151MB/s]
# 'dataset.zip'

# %%
import zipfile

with zipfile.ZipFile('dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('dataset') #unzip the dataset

# %%
import pickle

with open('dataset/input_data.pkl', 'rb') as f:
    data = pickle.load(f)



imgs = data['imgs']
masks = data['masks']

print( imgs.shape)
print(masks.shape)
# Out:
# (1305, 256, 256, 3)
# (1305, 256, 256, 1)

# %%
input_dir = imgs
target_dir = masks
img_size = (128, 128)
num_classes = 3 # the three pixels in the trimap mask
batch_size = 32

# %%
from PIL import Image
import matplotlib.pyplot as plt


# Display the first image in the dataset
first_image = imgs[9]  # Access the first image

# Check if the image needs to be converted to uint8 (common for display)
#first_image = first_image.astype('uint8')

# Display using PIL
img = Image.fromarray(first_image)
display(img)  # Or use `display(img)` in Jupyter Notebook


# Convert to PIL image and apply autocontrast
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# Ensure the mask is 2D by squeezing any singleton dimensions
first_mask = masks[9].squeeze().astype('uint8')  # Ensure the mask is 2D and in uint8 format

# Convert to PIL image and apply autocontrast
mask_img = Image.fromarray(first_mask)
mask_img_autocontrast = ImageOps.autocontrast(mask_img)

# Display the autocontrasted mask
display(mask_img_autocontrast)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=L size=256x256>

# %%
import tensorflow as tf

# Assuming you have already loaded your data
# imgs = data['imgs']  # Input images
# masks = data['masks']  # Target masks



# Create a TensorFlow dataset
def get_tf_dataset(images, masks, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((images, masks))
    dataset = dataset.batch(batch_size)
    return dataset

# Set your batch size

dataset = get_tf_dataset(imgs, masks, batch_size)

# Example: Iterate over the dataset and print shapes of batches
for img_batch, mask_batch in dataset.take(1):
    print("Image batch shape:", img_batch.shape)
    print("Mask batch shape:", mask_batch.shape)
# Out:
# Image batch shape: (32, 256, 256, 3)
# Mask batch shape: (32, 256, 256, 1)

# %%
import random
from sklearn.model_selection import train_test_split
train_size = 0.8  # 80% for training
val_size = 0.1    # 10% for validation
test_size = 0.1   # 10% for testing

# First, split off the test set
X_train, X_test, y_train, y_test = train_test_split(
    imgs, masks, test_size=test_size, random_state=42
)

# Then, split the training set into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=val_size/(1-test_size), random_state=42
)

# Check the shapes of the splits
print("Training images shape:", X_train.shape)
print("Training masks shape:", y_train.shape)
print("Validation images shape:", X_val.shape)
print("Validation masks shape:", y_val.shape)
print("Testing images shape:", X_test.shape)
print("Testing masks shape:", y_test.shape)

def create_tf_dataset(images, masks, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((images, masks))
    dataset = dataset.batch(batch_size)
    return dataset

# Create TensorFlow datasets
batch_size = 32
train_dataset = create_tf_dataset(X_train, y_train, batch_size)
val_dataset = create_tf_dataset(X_val, y_val, batch_size)
test_dataset = create_tf_dataset(X_test, y_test, batch_size)
# Out:
# Training images shape: (1043, 256, 256, 3)
# Training masks shape: (1043, 256, 256, 1)
# Validation images shape: (131, 256, 256, 3)
# Validation masks shape: (131, 256, 256, 1)
# Testing images shape: (131, 256, 256, 3)
# Testing masks shape: (131, 256, 256, 1)

# %%
def pixel_accuracy(y_true, y_pred):
    # Convert both to same type (float32)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # Round predictions to nearest integer
    y_pred_rounded = tf.round(y_pred)

    # Clip values to ensure they're in [0, 5] range
    y_pred_clipped = tf.clip_by_value(y_pred_rounded, 0, 5)

    # Compare predictions with ground truth
    correct_pixels = tf.cast(tf.equal(y_true, y_pred_clipped), tf.float32)

    # Calculate accuracy
    return tf.reduce_mean(correct_pixels)

# %%
import keras
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import io as tf_io
from keras.models import Model, load_model
from keras.layers import Input, Lambda, Dropout, Conv2D, Conv2DTranspose
from keras.layers import MaxPooling2D, concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K



def custom_sigmoid(x):

    return keras.activations.sigmoid(x)*5

filters = [8, 12, 16, 20, 24]
i = 0
## add a third dimension of value 3. We have RGB images
inputs =  Input(shape=(256, 256, 3))
#print(inputs.shape)
#s = Rescaling(1./255)(inputs)
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)
i+=1
c2 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)
i += 1
c3 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)
i += 1
c4 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
i += 1
c5 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c5)
i -= 1
### HERE ENDS ENCODER
u6 = Conv2DTranspose(filters[i], (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c6)
i -= 1
u7 = Conv2DTranspose(filters[i], (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c7)
i -= 1
u8 = Conv2DTranspose(filters[i], (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c8)
i -= 1
u9 = Conv2DTranspose(filters[i], (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(filters[i], (3, 3), activation='elu', kernel_initializer='he_normal',
            padding='same') (c9)

# Add a per-pixel classification layer
outputs = Conv2D(1, (1, 1), activation=custom_sigmoid)(c9)

model = Model(inputs=[inputs], outputs=[outputs])
lr = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='mse', metrics=[ pixel_accuracy])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 256, 256, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 8)    │            224 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256, 256, 8)    │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 8)    │            584 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 8)    │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 12)   │            876 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128, 128, 12)   │              0 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 12)   │          1,308 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 12)     │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 16)     │          1,744 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64, 64, 16)     │              0 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 16)     │          2,320 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 16)     │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 20)     │          2,900 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 32, 32, 20)     │              0 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 20)     │          3,620 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 20)     │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 16, 16, 24)     │          4,344 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 16, 16, 24)     │              0 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 24)     │          5,208 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 20)     │          1,940 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 40)     │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 20)     │          7,220 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 32, 32, 20)     │              0 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 20)     │          3,620 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 16)     │          1,296 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 32)     │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 16)     │          4,624 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 64, 64, 16)     │              0 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 16)     │          2,320 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 12)   │            780 │ conv2d_13[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 24)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 12)   │          2,604 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128, 128, 12)   │              0 │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 12)   │          1,308 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 8)    │            392 │ conv2d_15[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 16)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 256, 256, 8)    │          1,160 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 256, 256, 8)    │              0 │ conv2d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 256, 256, 8)    │            584 │ dropout_8[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 1)    │              9 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 50,985 (199.16 KB)
#  Trainable params: 50,985 (199.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
filepath = "model.keras"



#earlystopper = EarlyStopping(patience=5, verbose=1)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0,
                             save_best_only=True, mode='min')

callbacks_list = [checkpoint]

epochs = 100
history = model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=val_dataset,
    callbacks=callbacks_list,
    verbose=2,
)
# Out:
# Epoch 1/100
# 33/33 - 51s - 2s/step - loss: 1.5231 - pixel_accuracy: 0.4232 - val_loss: 0.7882 - val_pixel_accuracy: 0.4891
# Epoch 2/100
# 33/33 - 42s - 1s/step - loss: 0.6529 - pixel_accuracy: 0.6056 - val_loss: 0.8141 - val_pixel_accuracy: 0.3710
# Epoch 3/100
# 33/33 - 4s - 123ms/step - loss: 0.5972 - pixel_accuracy: 0.6396 - val_loss: 0.6553 - val_pixel_accuracy: 0.5636
# Epoch 4/100
# 33/33 - 4s - 126ms/step - loss: 0.5763 - pixel_accuracy: 0.6562 - val_loss: 0.5931 - val_pixel_accuracy: 0.5961
# Epoch 5/100
# 33/33 - 4s - 125ms/step - loss: 0.5538 - pixel_accuracy: 0.6719 - val_loss: 0.5462 - val_pixel_accuracy: 0.6195
# Epoch 6/100
# 33/33 - 5s - 155ms/step - loss: 0.5414 - pixel_accuracy: 0.6811 - val_loss: 0.5356 - val_pixel_accuracy: 0.6232
# Epoch 7/100
# 33/33 - 5s - 153ms/step - loss: 0.5295 - pixel_accuracy: 0.6908 - val_loss: 0.5363 - val_pixel_accuracy: 0.6265
# Epoch 8/100
# 33/33 - 5s - 155ms/step - loss: 0.5185 - pixel_accuracy: 0.6993 - val_loss: 0.5372 - val_pixel_accuracy: 0.6298
# Epoch 9/100
# 33/33 - 5s - 154ms/step - loss: 0.5116 - pixel_accuracy: 0.7067 - val_loss: 0.5625 - val_pixel_accuracy: 0.6269
# Epoch 10/100
# 33/33 - 4s - 125ms/step - loss: 0.5027 - pixel_accuracy: 0.7143 - val_loss: 0.5583 - val_pixel_accuracy: 0.6306
# Epoch 11/100
# 33/33 - 4s - 125ms/step - loss: 0.4978 - pixel_accuracy: 0.7182 - val_loss: 0.5586 - val_pixel_accuracy: 0.6330
# Epoch 12/100
# 33/33 - 5s - 156ms/step - loss: 0.4920 - pixel_accuracy: 0.7224 - val_loss: 0.5477 - val_pixel_accuracy: 0.6394
# Epoch 13/100
# 33/33 - 5s - 155ms/step - loss: 0.4883 - pixel_accuracy: 0.7253 - val_loss: 0.5553 - val_pixel_accuracy: 0.6399
# Epoch 14/100
# 33/33 - 5s - 154ms/step - loss: 0.4824 - pixel_accuracy: 0.7293 - val_loss: 0.5381 - val_pixel_accuracy: 0.6484
# Epoch 15/100
# 33/33 - 5s - 155ms/step - loss: 0.4801 - pixel_accuracy: 0.7308 - val_loss: 0.5384 - val_pixel_accuracy: 0.6490
# Epoch 16/100
# 33/33 - 4s - 128ms/step - loss: 0.4749 - pixel_accuracy: 0.7340 - val_loss: 0.5164 - val_pixel_accuracy: 0.6583
# Epoch 17/100
# 33/33 - 5s - 151ms/step - loss: 0.4767 - pixel_accuracy: 0.7331 - val_loss: 0.5170 - val_pixel_accuracy: 0.6552
# Epoch 18/100
# 33/33 - 5s - 155ms/step - loss: 0.4705 - pixel_accuracy: 0.7361 - val_loss: 0.5371 - val_pixel_accuracy: 0.6531
# Epoch 19/100
# 33/33 - 5s - 157ms/step - loss: 0.4670 - pixel_accuracy: 0.7392 - val_loss: 0.5111 - val_pixel_accuracy: 0.6602
# Epoch 20/100
# 33/33 - 4s - 127ms/step - loss: 0.4685 - pixel_accuracy: 0.7386 - val_loss: 0.4882 - val_pixel_accuracy: 0.6624
# Epoch 21/100
# 33/33 - 4s - 124ms/step - loss: 0.4612 - pixel_accuracy: 0.7423 - val_loss: 0.5878 - val_pixel_accuracy: 0.6435
# Epoch 22/100
# 33/33 - 4s - 124ms/step - loss: 0.4649 - pixel_accuracy: 0.7387 - val_loss: 0.5722 - val_pixel_accuracy: 0.6462
# Epoch 23/100
# 33/33 - 5s - 154ms/step - loss: 0.4667 - pixel_accuracy: 0.7392 - val_loss: 0.5465 - val_pixel_accuracy: 0.6544
# Epoch 24/100
# 33/33 - 4s - 125ms/step - loss: 0.4566 - pixel_accuracy: 0.7442 - val_loss: 0.5133 - val_pixel_accuracy: 0.6658
# Epoch 25/100
# 33/33 - 5s - 153ms/step - loss: 0.4556 - pixel_accuracy: 0.7454 - val_loss: 0.5141 - val_pixel_accuracy: 0.6613
# Epoch 26/100
# 33/33 - 4s - 124ms/step - loss: 0.4502 - pixel_accuracy: 0.7483 - val_loss: 0.5441 - val_pixel_accuracy: 0.6564
# Epoch 27/100
# 33/33 - 4s - 126ms/step - loss: 0.4560 - pixel_accuracy: 0.7440 - val_loss: 0.5187 - val_pixel_accuracy: 0.6648
# Epoch 28/100
# 33/33 - 4s - 124ms/step - loss: 0.4496 - pixel_accuracy: 0.7481 - val_loss: 0.4961 - val_pixel_accuracy: 0.6662
# Epoch 29/100
# 33/33 - 4s - 127ms/step - loss: 0.4525 - pixel_accuracy: 0.7458 - val_loss: 0.4544 - val_pixel_accuracy: 0.6845
# Epoch 30/100
# 33/33 - 5s - 153ms/step - loss: 0.4438 - pixel_accuracy: 0.7510 - val_loss: 0.4659 - val_pixel_accuracy: 0.6762
# Epoch 31/100
# 33/33 - 5s - 156ms/step - loss: 0.4427 - pixel_accuracy: 0.7515 - val_loss: 0.4453 - val_pixel_accuracy: 0.6862
# Epoch 32/100
# 33/33 - 5s - 154ms/step - loss: 0.4374 - pixel_accuracy: 0.7546 - val_loss: 0.4430 - val_pixel_accuracy: 0.6909
# Epoch 33/100
# 33/33 - 5s - 153ms/step - loss: 0.4357 - pixel_accuracy: 0.7550 - val_loss: 0.4632 - val_pixel_accuracy: 0.6816
# Epoch 34/100
# 33/33 - 5s - 154ms/step - loss: 0.4317 - pixel_accuracy: 0.7555 - val_loss: 0.4542 - val_pixel_accuracy: 0.6843
# Epoch 35/100
# 33/33 - 4s - 124ms/step - loss: 0.4302 - pixel_accuracy: 0.7552 - val_loss: 0.4551 - val_pixel_accuracy: 0.6857
# Epoch 36/100
# 33/33 - 5s - 154ms/step - loss: 0.4322 - pixel_accuracy: 0.7549 - val_loss: 0.4559 - val_pixel_accuracy: 0.6884
# Epoch 37/100
# 33/33 - 4s - 125ms/step - loss: 0.4262 - pixel_accuracy: 0.7583 - val_loss: 0.4497 - val_pixel_accuracy: 0.6897
# Epoch 38/100
# 33/33 - 4s - 129ms/step - loss: 0.4218 - pixel_accuracy: 0.7607 - val_loss: 0.4315 - val_pixel_accuracy: 0.6967
# Epoch 39/100
# 33/33 - 4s - 125ms/step - loss: 0.4203 - pixel_accuracy: 0.7617 - val_loss: 0.4450 - val_pixel_accuracy: 0.6958
# Epoch 40/100
# 33/33 - 4s - 124ms/step - loss: 0.4241 - pixel_accuracy: 0.7595 - val_loss: 0.4429 - val_pixel_accuracy: 0.7000
# Epoch 41/100
# 33/33 - 5s - 155ms/step - loss: 0.4294 - pixel_accuracy: 0.7562 - val_loss: 0.4423 - val_pixel_accuracy: 0.6948
# Epoch 42/100
# 33/33 - 5s - 154ms/step - loss: 0.4204 - pixel_accuracy: 0.7608 - val_loss: 0.4447 - val_pixel_accuracy: 0.6969
# Epoch 43/100
# 33/33 - 4s - 124ms/step - loss: 0.4174 - pixel_accuracy: 0.7624 - val_loss: 0.4675 - val_pixel_accuracy: 0.6902
# Epoch 44/100
# 33/33 - 5s - 154ms/step - loss: 0.4138 - pixel_accuracy: 0.7635 - val_loss: 0.4734 - val_pixel_accuracy: 0.6880
# Epoch 45/100
# 33/33 - 4s - 124ms/step - loss: 0.4160 - pixel_accuracy: 0.7633 - val_loss: 0.4565 - val_pixel_accuracy: 0.6923
# Epoch 46/100
# 33/33 - 4s - 124ms/step - loss: 0.4116 - pixel_accuracy: 0.7654 - val_loss: 0.4595 - val_pixel_accuracy: 0.6939
# Epoch 47/100
# 33/33 - 4s - 124ms/step - loss: 0.4118 - pixel_accuracy: 0.7652 - val_loss: 0.4807 - val_pixel_accuracy: 0.6872
# Epoch 48/100
# 33/33 - 4s - 125ms/step - loss: 0.4137 - pixel_accuracy: 0.7636 - val_loss: 0.4718 - val_pixel_accuracy: 0.6886
# Epoch 49/100
# 33/33 - 5s - 154ms/step - loss: 0.4134 - pixel_accuracy: 0.7641 - val_loss: 0.4460 - val_pixel_accuracy: 0.6950
# Epoch 50/100
# 33/33 - 4s - 125ms/step - loss: 0.4145 - pixel_accuracy: 0.7658 - val_loss: 0.4334 - val_pixel_accuracy: 0.7054
# Epoch 51/100
# 33/33 - 5s - 154ms/step - loss: 0.4106 - pixel_accuracy: 0.7651 - val_loss: 0.4478 - val_pixel_accuracy: 0.7008
# Epoch 52/100
# 33/33 - 5s - 154ms/step - loss: 0.4050 - pixel_accuracy: 0.7685 - val_loss: 0.4637 - val_pixel_accuracy: 0.6980
# Epoch 53/100
# 33/33 - 4s - 125ms/step - loss: 0.4053 - pixel_accuracy: 0.7681 - val_loss: 0.4847 - val_pixel_accuracy: 0.6856
# Epoch 54/100
# 33/33 - 5s - 153ms/step - loss: 0.4058 - pixel_accuracy: 0.7675 - val_loss: 0.5197 - val_pixel_accuracy: 0.6819
# Epoch 55/100
# 33/33 - 4s - 128ms/step - loss: 0.4105 - pixel_accuracy: 0.7656 - val_loss: 0.4310 - val_pixel_accuracy: 0.7041
# Epoch 56/100
# 33/33 - 5s - 152ms/step - loss: 0.4015 - pixel_accuracy: 0.7695 - val_loss: 0.4465 - val_pixel_accuracy: 0.7013
# Epoch 57/100
# 33/33 - 5s - 152ms/step - loss: 0.3965 - pixel_accuracy: 0.7724 - val_loss: 0.4328 - val_pixel_accuracy: 0.7012
# Epoch 58/100
# 33/33 - 4s - 125ms/step - loss: 0.3969 - pixel_accuracy: 0.7719 - val_loss: 0.4516 - val_pixel_accuracy: 0.7003
# Epoch 59/100
# 33/33 - 4s - 125ms/step - loss: 0.3951 - pixel_accuracy: 0.7740 - val_loss: 0.4409 - val_pixel_accuracy: 0.7083
# Epoch 60/100
# 33/33 - 4s - 124ms/step - loss: 0.3916 - pixel_accuracy: 0.7748 - val_loss: 0.4478 - val_pixel_accuracy: 0.7051
# Epoch 61/100
# 33/33 - 4s - 128ms/step - loss: 0.3905 - pixel_accuracy: 0.7758 - val_loss: 0.4302 - val_pixel_accuracy: 0.7140
# Epoch 62/100
# 33/33 - 5s - 156ms/step - loss: 0.3907 - pixel_accuracy: 0.7754 - val_loss: 0.4182 - val_pixel_accuracy: 0.7143
# Epoch 63/100
# 33/33 - 4s - 128ms/step - loss: 0.3901 - pixel_accuracy: 0.7758 - val_loss: 0.4168 - val_pixel_accuracy: 0.7117
# Epoch 64/100
# 33/33 - 4s - 125ms/step - loss: 0.3884 - pixel_accuracy: 0.7770 - val_loss: 0.4247 - val_pixel_accuracy: 0.7187
# Epoch 65/100
# 33/33 - 4s - 124ms/step - loss: 0.3850 - pixel_accuracy: 0.7786 - val_loss: 0.4261 - val_pixel_accuracy: 0.7181
# Epoch 66/100
# 33/33 - 5s - 158ms/step - loss: 0.3829 - pixel_accuracy: 0.7794 - val_loss: 0.4029 - val_pixel_accuracy: 0.7276
# Epoch 67/100
# 33/33 - 5s - 151ms/step - loss: 0.3822 - pixel_accuracy: 0.7790 - val_loss: 0.4244 - val_pixel_accuracy: 0.7225
# Epoch 68/100
# 33/33 - 5s - 155ms/step - loss: 0.3817 - pixel_accuracy: 0.7801 - val_loss: 0.4181 - val_pixel_accuracy: 0.7176
# Epoch 69/100
# 33/33 - 4s - 124ms/step - loss: 0.3808 - pixel_accuracy: 0.7805 - val_loss: 0.4153 - val_pixel_accuracy: 0.7188
# Epoch 70/100
# 33/33 - 4s - 124ms/step - loss: 0.3782 - pixel_accuracy: 0.7818 - val_loss: 0.4143 - val_pixel_accuracy: 0.7185
# Epoch 71/100
# 33/33 - 5s - 155ms/step - loss: 0.3793 - pixel_accuracy: 0.7826 - val_loss: 0.4316 - val_pixel_accuracy: 0.7123
# Epoch 72/100
# 33/33 - 5s - 153ms/step - loss: 0.3794 - pixel_accuracy: 0.7832 - val_loss: 0.4055 - val_pixel_accuracy: 0.7279
# Epoch 73/100
# 33/33 - 4s - 124ms/step - loss: 0.3771 - pixel_accuracy: 0.7826 - val_loss: 0.4122 - val_pixel_accuracy: 0.7210
# Epoch 74/100
# 33/33 - 5s - 156ms/step - loss: 0.3742 - pixel_accuracy: 0.7839 - val_loss: 0.4088 - val_pixel_accuracy: 0.7252
# Epoch 75/100
# 33/33 - 4s - 124ms/step - loss: 0.3732 - pixel_accuracy: 0.7850 - val_loss: 0.4094 - val_pixel_accuracy: 0.7329
# Epoch 76/100
# 33/33 - 4s - 124ms/step - loss: 0.3745 - pixel_accuracy: 0.7838 - val_loss: 0.4282 - val_pixel_accuracy: 0.7195
# Epoch 77/100
# 33/33 - 4s - 126ms/step - loss: 0.3732 - pixel_accuracy: 0.7841 - val_loss: 0.4159 - val_pixel_accuracy: 0.7242
# Epoch 78/100
# 33/33 - 4s - 128ms/step - loss: 0.3734 - pixel_accuracy: 0.7850 - val_loss: 0.3994 - val_pixel_accuracy: 0.7318
# Epoch 79/100
# 33/33 - 4s - 124ms/step - loss: 0.3747 - pixel_accuracy: 0.7824 - val_loss: 0.4042 - val_pixel_accuracy: 0.7275
# Epoch 80/100
# 33/33 - 4s - 125ms/step - loss: 0.3742 - pixel_accuracy: 0.7857 - val_loss: 0.4026 - val_pixel_accuracy: 0.7376
# Epoch 81/100
# 33/33 - 5s - 154ms/step - loss: 0.3745 - pixel_accuracy: 0.7850 - val_loss: 0.4053 - val_pixel_accuracy: 0.7339
# Epoch 82/100
# 33/33 - 5s - 154ms/step - loss: 0.3688 - pixel_accuracy: 0.7884 - val_loss: 0.3994 - val_pixel_accuracy: 0.7403
# Epoch 83/100
# 33/33 - 4s - 125ms/step - loss: 0.3659 - pixel_accuracy: 0.7902 - val_loss: 0.4001 - val_pixel_accuracy: 0.7440
# Epoch 84/100
# 33/33 - 4s - 125ms/step - loss: 0.3701 - pixel_accuracy: 0.7904 - val_loss: 0.4035 - val_pixel_accuracy: 0.7398
# Epoch 85/100
# 33/33 - 4s - 124ms/step - loss: 0.3677 - pixel_accuracy: 0.7893 - val_loss: 0.4042 - val_pixel_accuracy: 0.7441
# Epoch 86/100
# 33/33 - 5s - 160ms/step - loss: 0.3652 - pixel_accuracy: 0.7904 - val_loss: 0.3928 - val_pixel_accuracy: 0.7472
# Epoch 87/100
# 33/33 - 4s - 124ms/step - loss: 0.3636 - pixel_accuracy: 0.7923 - val_loss: 0.4205 - val_pixel_accuracy: 0.7354
# Epoch 88/100
# 33/33 - 4s - 127ms/step - loss: 0.3600 - pixel_accuracy: 0.7929 - val_loss: 0.3831 - val_pixel_accuracy: 0.7497
# Epoch 89/100
# 33/33 - 5s - 151ms/step - loss: 0.3589 - pixel_accuracy: 0.7944 - val_loss: 0.3881 - val_pixel_accuracy: 0.7541
# Epoch 90/100
# 33/33 - 5s - 155ms/step - loss: 0.3629 - pixel_accuracy: 0.7929 - val_loss: 0.4161 - val_pixel_accuracy: 0.7407
# Epoch 91/100
# 33/33 - 4s - 127ms/step - loss: 0.3649 - pixel_accuracy: 0.7924 - val_loss: 0.3745 - val_pixel_accuracy: 0.7490
# Epoch 92/100
# 33/33 - 5s - 152ms/step - loss: 0.3647 - pixel_accuracy: 0.7926 - val_loss: 0.3897 - val_pixel_accuracy: 0.7410
# Epoch 93/100
# 33/33 - 5s - 153ms/step - loss: 0.3596 - pixel_accuracy: 0.7939 - val_loss: 0.3831 - val_pixel_accuracy: 0.7490
# Epoch 94/100
# 33/33 - 5s - 155ms/step - loss: 0.3571 - pixel_accuracy: 0.7955 - val_loss: 0.3916 - val_pixel_accuracy: 0.7485
# Epoch 95/100
# 33/33 - 4s - 125ms/step - loss: 0.3576 - pixel_accuracy: 0.7972 - val_loss: 0.3833 - val_pixel_accuracy: 0.7540
# Epoch 96/100
# 33/33 - 4s - 124ms/step - loss: 0.3539 - pixel_accuracy: 0.7984 - val_loss: 0.3797 - val_pixel_accuracy: 0.7527
# Epoch 97/100
# 33/33 - 4s - 124ms/step - loss: 0.3543 - pixel_accuracy: 0.7978 - val_loss: 0.3904 - val_pixel_accuracy: 0.7516
# Epoch 98/100
# 33/33 - 5s - 157ms/step - loss: 0.3533 - pixel_accuracy: 0.7982 - val_loss: 0.3848 - val_pixel_accuracy: 0.7498
# Epoch 99/100
# 33/33 - 4s - 124ms/step - loss: 0.3572 - pixel_accuracy: 0.7976 - val_loss: 0.3925 - val_pixel_accuracy: 0.7429
# Epoch 100/100
# 33/33 - 4s - 124ms/step - loss: 0.3549 - pixel_accuracy: 0.7992 - val_loss: 0.4087 - val_pixel_accuracy: 0.7401

# %%
# use the best model epoch
model.load_weights('model.keras')

test_preds = model.predict(test_dataset)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step

# %%
test_preds[0].shape
# Out:
# (256, 256, 1)

# %%
model.load_weights('model.keras')

# Get one batch from test dataset
for images, masks in test_dataset.take(2):
    # Get predictions for this batch
    predictions = model.predict(images)

    # Take first image from the batch
    original_image = images[0]
    original_mask = masks[0]
    predicted_mask = predictions[0]

    # Convert to displayable images
    original_img = tf.keras.utils.array_to_img(original_image)
    mask_img = tf.keras.utils.array_to_img(original_mask)
    pred_img = tf.keras.utils.array_to_img(predicted_mask)

    # Display all three
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.title('Original Image')
    plt.imshow(original_img)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title('True Mask')
    plt.imshow(mask_img)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title('Predicted Mask')
    plt.imshow(pred_img)
    plt.axis('off')

    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
